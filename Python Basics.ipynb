# %%
print("Hello World")
# Out:
# Hello World

# %%
x=5;
y=4;
print(x+y);
# Out:
# 9

# %%
x=10;
y=2;
print(x/y);
# Out:
# 5.0

# %%
x=10;
y=2;
print(x-y);
# Out:
# 8

# %%
x=10;
y=2;
print(x*y);
# Out:
# 20

# %%
x=10;
y=2;
print(x%y);
# Out:
# 0

# %%
a=int(input("enter a number"))
print(a**2)
# Out:
# enter a number2
# 4

# %%
r=float(input("enter radius"))
print(3.14*r**2)
# Out:
# enter radius1.1
# 3.7994000000000008

# %%
x=4
y=3
z=(x+y)*(x+y)
print(z)
# Out:
# 49

# %%
str1='dheepika'
str2='ray'
concat=str1+str2
print(concat)
# Out:
# dheepikaray

# %%
a='hello'
b=20
c=a+str(b)
print(c)
# Out:
# hello20

# %%
a=20
b=30
c=str(a)+str(b)
print(c)
print(type(b))
# Out:
# 2030
# <class 'int'>

# %%
A = 'hello'
B = 2023
print(A+str(B))
# Out:
# hello2023
