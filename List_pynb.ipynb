# %%
list1=["apple","banana","cherry"]
print(list1)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1=["apple","banana","cherry"]
print(list[1])
# Out:
# list[1]

# %%
list1=["apple","banana","cherry"]
list1.append("mango")
print(list1)
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
list1=["apple","banana","cherry"]
list1[0]="mango"
print(list1)
# Out:
# ['mango', 'banana', 'cherry']

# %%
list1=["apple","banana","cherry"]
list1.insert(1,"mango")
print(list1)
# Out:
# ['apple', 'mango', 'banana', 'cherry']

# %%
list1=["apple","banana","cherry"]
del(list1[0])
print(list1)
# Out:
# ['banana', 'cherry']

# %%
list1=["apple","banana","cherry"]
list1.remove("apple")
print(list1)
# Out:
# ['banana', 'cherry']

# %%
list1=["apple","banana","cherry"]
list1.clear()
print(list1)
# Out:
# []

# %%
list1=["apple","banana","cherry"]
n=len(list1)
print(n)
# Out:
# 3

# %%
list2=[1,2,3,4,5,6,6,7,7,8,9,]
print(list2)
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7, 7, 8, 9]

# %%
list2=[1,2,3,4,5,6,6,7,7,8,9,]
c=list2.count(7)
print("count=",c)
# Out:
# count= 2

# %%
list2=[1,2,3,4,5,6,6,7,7,8,9]
print(list2[-2]) #print index 2 from last
# Out:
# 8

# %%
list3=['athira','dheepika','farhana','abinanth','vignesh']
print(list3[2:5]) #values from 2 upto 4
# Out:
# ['farhana', 'abinanth', 'vignesh']

# %%
list3=['athira','dheepika','farhana','abinanth','vignesh']
print(list3[:5]) #print whole list
# Out:
# ['athira', 'dheepika', 'farhana', 'abinanth', 'vignesh']

# %%
list3=['athira','dheepika','farhana','abinanth','vignesh']
print(list3[2:]) #print after index 2
# Out:
# ['farhana', 'abinanth', 'vignesh']

# %%
list3=['athira','dheepika','farhana','abinanth','vignesh']
print(list3[-2:])
# Out:
# ['abinanth', 'vignesh']

# %%
list3=['athira','dheepika','farhana','abinanth','vignesh']
print(list3[:-1])
print(list3[1:-1])
print(list3[-4:-1])
# Out:
# ['athira', 'dheepika', 'farhana', 'abinanth']
# ['dheepika', 'farhana', 'abinanth']
# ['dheepika', 'farhana', 'abinanth']

# %%
list4=[2,1,5,8,3,5]
list4.sort()
print(list4)
# Out:
# [1, 2, 3, 5, 5, 8]

# %%
list4=[2,1,5,8,3,5]
list4.sort(reverse=True)
print(list4)
# Out:
# [8, 5, 5, 3, 2, 1]
